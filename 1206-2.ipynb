# %%
import os
import shutil
import re
import subprocess
import urllib
import zipfile
import requests


"""
Scrapes and installs chromium from linux mint 21.3(virginia) packages site.
Link: http://packages.linuxmint.com/pool/upstream/c/chromium/
Scrapes and installs chromedriver from Chrome for Testing page.
Link: https://googlechromelabs.github.io/chrome-for-testing/
"""

class CantGetLatestChromiumVersionError(Exception):
    """Happens when regex failed"""

class ChromiumInstallationFailedException(Exception):
    """
    Happens when deb package not installed
    Check the downloaded chroumium deb file
    """

class CantGetChromeDriverError(Exception):
    """Happens when regex failed"""

main_url = "http://packages.linuxmint.com/pool/upstream/c/chromium/"
work_dir = "/content"

def get_chromium_latest_version() -> str:
    # A request to packages.linuxmint.com for getting latest version of chromium
    # e.g. "chromium_121.0.6167.160~linuxmint1+virginia_amd64.deb"
    r = requests.get(main_url)
    if r.status_code != 200:
        raise Exception("status_code code not 200!")
    text = r.text

    # Find latest version
    pattern = '<a\shref="(chromium_[^"]+linuxmint1%2Bvirginia_amd64.deb)'
    latest_version_search = re.search(pattern, text)
    if latest_version_search:
        latest_version = latest_version_search.group(1)
    else:
        raise CantGetLatestChromiumVersionError("Failed to get latest chromium version!")
    return latest_version

def install_chromium(latest_version: str, deb_file: str, quiet: bool):
    # Full url of deb file
    url = f"{main_url}{latest_version}"

    # Download deb file
    if quiet:
        command = f"wget -q -O {work_dir}/{deb_file} {url}"
    else:
        command = f"wget -O {work_dir}/{deb_file} {url}"
    print(f"Downloading: {deb_file}")
    # os.system(command)
    # !$command

    # Install deb file
    if quiet:
        command = f"apt-get install {work_dir}/{deb_file} >> apt.log"
    else:
        command = f"apt-get install {work_dir}/{deb_file}"
    print(f"Installing: {deb_file}")
    # os.system(command)
    # !$command

def check_chromium_installation(deb_file: str):
    try:
        subprocess.call(["chromium"])
        print("Chromium installation successfull.\n")
        # If installation successfull we can remove deb file
        # Delete deb file from disk
        os.remove(f"{work_dir}/{deb_file}")
    except FileNotFoundError:
        raise ChromiumInstallationFailedException("Chromium Installation Failed!")

def get_chromedriver_url(deb_file: str) -> str:
    # Get content of crhomedriver page
    url = "https://googlechromelabs.github.io/chrome-for-testing/"
    r = requests.get(url)
    if r.status_code != 200:
        raise Exception("status_code code not 200!")
    text = r.text

    # Get chromium version from deb file's name
    version_number = deb_file.split("chromium_")[-1].split(".")[0]

    # Example: https://edgedl.me.gvt1.com/edgedl/chrome/chrome-for-testing/121.0.6167.85/linux64/chromedriver-linux64.zip
    pattern = f'https://[^<]+/{version_number}[^<]+/linux64/chromedriver-linux64.zip'
    # Find latest version
    chromedriver_url_search = re.search(pattern, text)
    if chromedriver_url_search:
        chromedriver_url = chromedriver_url_search.group()
        return chromedriver_url
    else:
        raise CantGetChromeDriverError("Failed to get chromedriver!")

def install_chromedriver(deb_file: str, quiet: bool):
    url = get_chromedriver_url(deb_file)
    file_name = url.split("/")[-1]
    # Download chromedriver
    chromedriver_zip = f"{work_dir}/{file_name}"
    if quiet:
        command = f"wget -q -O {chromedriver_zip} {url}"
    else:
        command = f"wget -O {chromedriver_zip} {url}"
    print(f"Downloading: {file_name}")
    # os.system(command)
    # !$command

    # Extract chromedriver from zip
    with zipfile.ZipFile(chromedriver_zip) as zpf:
        zpf.extract(member="chromedriver-linux64/chromedriver", path=work_dir)

    # Remove chromedriver-linux64.zip file
    os.remove(chromedriver_zip)

    # Move extracted chromedriver binary file to /usr/bin directory
    source = f"{work_dir}/chromedriver-linux64/chromedriver"
    destination = "/usr/bin/chromedriver"
    os.rename(source, destination)

    # Make chromedriver binary executable
    os.system(f"chmod +x {destination}")

    # Remove empty chromedriver-linux64 folder
    shutil.rmtree(f"{work_dir}/chromedriver-linux64")

    print("Chromedriver installed")

def install_selenium_package(quiet: bool):
    if quiet:
        # !pip install selenium -qq >> pip.log
    else:
        # !pip install selenium

def main(quiet: bool):
    # Get the latest version of chromium from linux mint packages site
    latest_version = get_chromium_latest_version()
    # Name of the deb file
    deb_file = urllib.parse.unquote(latest_version, "utf-8")
    # Download and install chromium for ubuntu 22.04
    install_chromium(latest_version, deb_file, quiet)
    # Check if installation succesfull
    check_chromium_installation(deb_file)
    # Install chromedriver
    install_chromedriver(deb_file, quiet)
    # Finally install selenium package
    install_selenium_package(quiet)

if __name__ == '__main__':
    quiet = True # verboseness of wget and apt
    main(quiet)
# Out:
# Downloading: chromium_131.0.6778.85~linuxmint1+virginia_amd64.deb
# Installing: chromium_131.0.6778.85~linuxmint1+virginia_amd64.deb
# Chromium installation successfull.
#
# Downloading: chromedriver-linux64.zip
# Chromedriver installed

# %%
import os
import time
import csv
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# 定義 Selenium 的選項
options = webdriver.ChromeOptions()
options.add_argument('--headless')  # 啟用無頭模式
options.add_argument('--no-sandbox')  # 避免權限問題
options.add_argument('--disable-dev-shm-usage')  # 防止資源問題
options.add_argument('--disable-gpu')  # 禁用 GPU 渲染（僅限 Windows）

# 設定 ChromeDriver 路徑
chrome_driver_path = 'chromedriver'
driver = webdriver.Chrome(options=options)

# 定義 Imgur 搜索 URL
search_url = "https://imgur.com/search?q=cat"
driver.get(search_url)

# 模擬滾動 10 次以加載更多圖片
for _ in range(10):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(2)  # 等待新內容加載

# 解析網頁內容
soup = BeautifulSoup(driver.page_source, 'html.parser')
driver.quit()

# 提取圖片 URL
image_elements = soup.find_all("img")
image_urls = [img["src"] for img in image_elements if "src" in img.attrs]

# 處理完整的圖片 URL（有些是相對 URL，需要補上 "https:"）
full_image_urls = ["https:" + url if url.startswith("//") else url for url in image_urls]

# 將圖片 URL 寫入 CSV 文件
csv_file = "cat_images.csv"
with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["img-src"])  # 標題行
    writer.writerows([[url] for url in full_image_urls])

print(f"CSV 檔案已保存：{csv_file}")
# Out:
# CSV 檔案已保存：cat_images.csv

# %%
#使用requests
import csv
import requests
import os

# 創建文件夾
os.makedirs("images", exist_ok=True)

# 讀取 CSV
with open("cat_images.csv", "r") as file:
    reader = csv.DictReader(file)
    for row in reader:
        url = row["img-src"]
        filename = os.path.join("images", url.split("/")[-1])  # 使用圖片的名稱
        try:
            response = requests.get(url, stream=True)
            with open(filename, "wb") as img_file:
                for chunk in response.iter_content(1024):
                    img_file.write(chunk)
            print(f"下載完成: {filename}")
        except Exception as e:
            print(f"下載失敗: {url} - {e}")
# Out:
# 下載完成: images/UXCBWlWb.jpg
# 下載完成: images/ZhP2zUWb.jpg
# 下載完成: images/NUyttbnb.jpg
# 下載完成: images/O3EIPHpb.jpg
# 下載完成: images/jIZKh2sb.jpg
# 下載完成: images/ZZpVeoYb.jpg
# 下載完成: images/6tCJw81b.jpg
# 下載完成: images/vGla0Wxb.jpg
# 下載完成: images/U0iADj9b.jpg
# 下載完成: images/ggQUrJ9b.jpg
# 下載完成: images/mtbl1crb.jpg
# 下載完成: images/lVlPvCBb.jpg
# 下載完成: images/c5puGf3b.jpg
# 下載完成: images/grXqcNwb.jpg
# 下載完成: images/0sa6jrVb.jpg
# 下載完成: images/pbao8mhb.jpg
# 下載完成: images/X6DesPeb.jpg
# 下載完成: images/jhcN1Keb.jpg
# 下載完成: images/35QDIiFb.jpg
# 下載完成: images/nqcMAk0b.jpg
# 下載完成: images/3Qmaql6b.jpg
# 下載完成: images/Ejn0Yvib.jpg
# 下載完成: images/fqd9uUjb.jpg
# 下載完成: images/DIhbSrbb.jpg
# 下載完成: images/ymg1iqyb.jpg
# 下載完成: images/frKhsH4b.jpg
# 下載完成: images/0LINzxsb.jpg
# 下載完成: images/f4jZRrtb.jpg
# 下載完成: images/VMDIqHjb.jpg
# 下載完成: images/0Y1b8Xvb.jpg
# 下載完成: images/jZiyxAUb.jpg
# 下載完成: images/L20W8JHb.jpg
# 下載完成: images/Jvh1OQmb.jpg
# 下載完成: images/KWvtdg0b.jpg
# 下載完成: images/lJJZVRvb.jpg
# 下載完成: images/JZn9Hysb.jpg
# 下載完成: images/qBtvSZsb.jpg
# 下載完成: images/vLPhacab.jpg
# 下載完成: images/sRLWmUhb.jpg
# 下載完成: images/LbPsLrCb.jpg
# 下載完成: images/diUuYJCb.jpg
# 下載完成: images/YBwfhueb.jpg
# 下載完成: images/rFBiyeRb.jpg
# 下載完成: images/Qhyj95Ub.jpg
# 下載完成: images/Uschhegb.jpg
# 下載完成: images/QNqcDwJb.jpg
# 下載完成: images/Z3fFFcjb.jpg
# 下載完成: images/k5SyHiVb.jpg
# 下載完成: images/ujAO1Dlb.jpg
# 下載完成: images/PJB6lKdb.jpg
# 下載完成: images/hjIugM0b.jpg
# 下載完成: images/fAWiERgb.jpg
# 下載完成: images/5Pt7P3gb.jpg
# 下載完成: images/e5LvUqrb.jpg
# 下載完成: images/7htAY2eb.jpg
# 下載完成: images/XJoDUTXb.jpg
# 下載完成: images/ufdNaP2b.jpg
# 下載完成: images/YV8DNtrb.jpg
# 下載完成: images/DfEvI67b.jpg
# 下載完成: images/JpulC5ab.jpg
# 下載完成: images/9AYsBSUb.jpg
# 下載完成: images/3Xcehfnb.jpg
# 下載完成: images/8FkatJHb.jpg
# 下載完成: images/dqYeUK4b.jpg
# 下載完成: images/Pr3on8ob.jpg
# 下載完成: images/eTxzk46b.jpg
# 下載完成: images/OoelXO5b.jpg
# 下載完成: images/qEoWZoWb.jpg
# 下載完成: images/JOKsNeTb.jpg
# 下載完成: images/vxhjk3ob.jpg
# 下載完成: images/hddwPKPb.jpg
# 下載完成: images/OsU4fAOb.jpg
# 下載完成: images/QxR8tQhb.jpg
# 下載完成: images/BfKkgr1b.jpg
# 下載完成: images/Ru2pLy3b.jpg
# 下載完成: images/w1KqyiOb.jpg
# 下載完成: images/aSkyXB5b.jpg
# 下載完成: images/N88OL8qb.jpg
# 下載完成: images/BVXJnLVb.jpg
# 下載完成: images/R2fAdiyb.jpg
# 下載完成: images/tU50Ek2b.jpg
# 下載完成: images/rEWZzhjb.jpg
# 下載完成: images/7w9fV1Fb.jpg
# 下載完成: images/igt12tfb.jpg
# 下載完成: images/P1uOn6ob.jpg
# 下載完成: images/Ve9zZPXb.jpg
# 下載完成: images/ZoUhyFib.jpg
# 下載完成: images/CU8oNkFb.jpg
# 下載完成: images/ZfqEtUwb.jpg
# 下載完成: images/VpnKfhlb.jpg
# 下載完成: images/liLjByeb.jpg
# 下載完成: images/LuyQkcVb.jpg
# 下載完成: images/jlFgGpeb.jpg
# 下載完成: images/OvxI2fzb.jpg
# 下載完成: images/iRJmCUtb.jpg
# 下載完成: images/434Krf8b.jpg
# 下載完成: images/3zZVI9hb.jpg
# 下載完成: images/OoFZxMAb.jpg
# 下載完成: images/wmzhNm4b.jpg
# 下載完成: images/oXxTj5gb.jpg
# 下載完成: images/zxcBhgcb.jpg
# 下載完成: images/yNjduNRb.jpg
# 下載完成: images/WpPtWdcb.jpg
# 下載完成: images/Rkwfvnrb.jpg
# 下載完成: images/zmFFej3b.jpg
# 下載完成: images/OM1jAhsb.jpg
# 下載完成: images/uNTkO5Bb.jpg
# 下載完成: images/k4WIstOb.jpg
# 下載完成: images/nJnD26rb.jpg
# 下載完成: images/zVJqCTUb.jpg
# 下載完成: images/yOGo3fzb.jpg
# 下載完成: images/C7k2UDwb.jpg
# 下載完成: images/NMN73lpb.jpg
# 下載完成: images/J2HZir3b.jpg
# 下載完成: images/E3aGgDwb.jpg
# 下載完成: images/Wix5R0Ob.jpg
# 下載完成: images/1vH34JSb.jpg
# 下載完成: images/l1QfJMMb.jpg
# 下載完成: images/dVCyFZmb.jpg
# 下載完成: images/pIUsuyEb.jpg
# 下載完成: images/bkSsswlb.jpg
# 下載完成: images/OjcuVrvb.jpg
# 下載完成: images/ozEaj1Zb.jpg
# 下載完成: images/fp75vQub.jpg
# 下載完成: images/qSAeD7Hb.jpg
# 下載完成: images/1QHrGq0b.jpg
# 下載完成: images/dV2CgPhb.jpg
# 下載完成: images/0U70ofNb.jpg
# 下載完成: images/B0D4iRkb.jpg
# 下載完成: images/VIYKW9mb.jpg
# 下載完成: images/Q16DJgNb.jpg
# 下載完成: images/gtgpi1Yb.jpg
# 下載完成: images/zXYtzKKb.jpg
# 下載完成: images/UfZubEIb.jpg
# 下載完成: images/kwZFyk8b.jpg
# 下載完成: images/dJXKJo7b.jpg
# 下載完成: images/toJSiALb.jpg
# 下載完成: images/hlN3NZZb.jpg
# 下載完成: images/NwFYgvsb.jpg
# 下載完成: images/tlmrjXFb.jpg
# 下載完成: images/WhkIn0eb.jpg
# 下載完成: images/5R1RwUsb.jpg
# 下載完成: images/ujYI9SFb.jpg
# 下載完成: images/TfJ2cvSb.jpg
# 下載完成: images/zfnWyXVb.jpg
# 下載完成: images/i8YkPLfb.jpg
# 下載完成: images/xSQeKSsb.jpg
# 下載完成: images/fMOAEdlb.jpg
# 下載完成: images/heZzYebb.jpg
# 下載完成: images/kIvHdPtb.jpg
# 下載完成: images/S32Dztqb.jpg
# 下載完成: images/LOsgqrSb.jpg
# 下載完成: images/85kT9xPb.jpg
# 下載完成: images/jLOmn3kb.jpg
# 下載完成: images/RtgvtAAb.jpg
# 下載完成: images/mdja1Txb.jpg
# 下載完成: images/unuSwWob.jpg
# 下載完成: images/JTf2Mk6b.jpg
# 下載完成: images/QX7L70gb.jpg
# 下載完成: images/S9BIP6Fb.jpg
# 下載完成: images/FnmRIGib.jpg
# 下載完成: images/BRVYmCub.jpg
# 下載完成: images/WktFupPb.jpg
# 下載完成: images/iuyqzOpb.jpg
# 下載完成: images/8jlcB7db.jpg
# 下載完成: images/kqyg254b.jpg
# 下載完成: images/jRZRrCGb.jpg
# 下載完成: images/Bmi17lNb.jpg
# 下載完成: images/52sZfRLb.jpg
# 下載完成: images/UTSUiElb.jpg
# 下載完成: images/meMUn3Rb.jpg
# 下載完成: images/De4fIGxb.jpg
# 下載完成: images/tquq1Isb.jpg
# 下載完成: images/l32Mp0Hb.jpg
# 下載完成: images/NZ0HnG5b.jpg
# 下載完成: images/qPkJUaub.jpg
# 下載完成: images/jzXn8Scb.jpg
# 下載完成: images/2oTdDKFb.jpg
# 下載完成: images/IzSO9Rtb.jpg
# 下載完成: images/xeNzAxBb.jpg
# 下載完成: images/6epuMKKb.jpg
# 下載完成: images/JcgPw40b.jpg
# 下載完成: images/5exkc7pb.jpg
# 下載完成: images/7cBJ59rb.jpg
# 下載完成: images/zmJ13hXb.jpg
# 下載完成: images/cw3WTu4b.jpg
# 下載完成: images/OepfRKQb.jpg
# 下載完成: images/SOxcr2Qb.jpg
# 下載完成: images/QbgBBjZb.jpg
# 下載完成: images/18nauQlb.jpg
# 下載完成: images/agjj2s3b.jpg
# 下載完成: images/J1NAbpfb.jpg
# 下載完成: images/HaJrfmLb.jpg
# 下載完成: images/gfT5h68b.jpg
# 下載完成: images/lK9xrXWb.jpg
# 下載完成: images/J2fYl0Db.jpg
# 下載完成: images/PVtCusob.jpg
# 下載完成: images/D6Gv2ydb.jpg
# 下載完成: images/wrlhcY1b.jpg
# 下載完成: images/WRtHFuMb.jpg
# 下載完成: images/657bSNWb.jpg
# 下載完成: images/y3Dc5BAb.jpg
# 下載完成: images/mR1qwDJb.jpg
# 下載完成: images/JukrWhHb.jpg
# 下載完成: images/uBSTj2ab.jpg
# 下載完成: images/7zaQKssb.jpg
# 下載完成: images/5aqYCXtb.jpg
# 下載完成: images/UcUZ4AIb.jpg
# 下載完成: images/1ZUcUUKb.jpg
# 下載完成: images/Lanthobb.jpg
# 下載完成: images/FpDO4Ucb.jpg
# 下載完成: images/3cL9JSAb.jpg
# 下載完成: images/oIg72Teb.jpg
# 下載完成: images/CbSZnFyb.jpg
# 下載完成: images/SjZhAF8b.jpg
# 下載完成: images/04EQtM6b.jpg
# 下載完成: images/fexRT8Gb.jpg
# 下載完成: images/A4G7i9Hb.jpg
# 下載完成: images/fksj6bVb.jpg
# 下載完成: images/xzpANj3b.jpg
# 下載完成: images/PP2cirEb.jpg
# 下載完成: images/Z3pmDa5b.jpg
# 下載完成: images/Dy3BD3pb.jpg
# 下載完成: images/Is95zHgb.jpg
# 下載完成: images/VPBKvTCb.jpg
# 下載完成: images/slUzNtqb.jpg
# 下載完成: images/Ga3yqA2b.jpg
# 下載完成: images/uSOp5odb.jpg
# 下載完成: images/8pplk2qb.jpg
# 下載完成: images/y4cq9tBb.jpg
# 下載完成: images/4SKbUmRb.jpg
# 下載完成: images/YaiVZBvb.jpg
# 下載完成: images/GESFovGb.jpg
# 下載完成: images/Qsme7vAb.jpg
# 下載完成: images/Uvw8UXzb.jpg
# 下載完成: images/tWPf0gob.jpg
# 下載完成: images/QOROM0hb.jpg
# 下載完成: images/FD8rNR7b.jpg
# 下載完成: images/tsGsKydb.jpg
# 下載完成: images/6SyNzelb.jpg
# 下載完成: images/q7BbfHtb.jpg
# 下載完成: images/XZOuZfmb.jpg
# 下載完成: images/3I03ggQb.jpg
# 下載完成: images/QjKA8oDb.jpg
# 下載完成: images/jbJRVEVb.jpg
# 下載完成: images/2k6yvyHb.jpg
# 下載完成: images/6nE7C5Kb.jpg
# 下載完成: images/rdRyZtGb.jpg
# 下載完成: images/7rnuhJrb.jpg
# 下載完成: images/b8XsHGzb.jpg
# 下載完成: images/jSTK1u4b.jpg
# 下載完成: images/34hntxyb.jpg
# 下載完成: images/GdFMS9Db.jpg
# 下載完成: images/ogVcpNgb.jpg
# 下載完成: images/0FbkiKeb.jpg
# 下載完成: images/EPatvsDb.jpg
# 下載完成: images/cojcul7b.jpg
# 下載完成: images/VMEFPRmb.jpg
# 下載完成: images/GXiO89bb.jpg
# 下載完成: images/kguMWVHb.jpg
# 下載完成: images/ewo7nofb.jpg
# 下載完成: images/iWp0oTPb.jpg
# 下載完成: images/Dn4YNJ1b.jpg
# 下載完成: images/qzoPCbGb.jpg
# 下載完成: images/Q8E8fW9b.jpg
# 下載完成: images/BYuQpLQb.jpg
# 下載完成: images/zsxa09Db.jpg
# 下載完成: images/Ehj6cu2b.jpg
# 下載完成: images/9B5C2wDb.jpg
# 下載完成: images/Vf3QF47b.jpg
# 下載完成: images/mPIbHwmb.jpg
# 下載完成: images/Yg3fTvMb.jpg
# 下載完成: images/xzryUw3b.jpg
# 下載完成: images/xGmX4h3b.jpg
# 下載完成: images/5hDHimpb.jpg
# 下載完成: images/Fsbud2ob.jpg
# 下載完成: images/K9YWnXIb.jpg
# 下載完成: images/VRhI3Tdb.jpg
# 下載完成: images/ZsHwTtub.jpg
# 下載完成: images/lcu2DKMb.jpg
# 下載完成: images/rutUY3wb.jpg
# 下載完成: images/l1lCNrMb.jpg
# 下載完成: images/Qauo8cmb.jpg
# 下載完成: images/EXO8VwTb.jpg
# 下載完成: images/CZhbPM1b.jpg
# 下載完成: images/L3VgGXMb.jpg
# 下載完成: images/vCzLYvqb.jpg
# 下載完成: images/mOAKKqjb.jpg
# 下載完成: images/oqkxKTMb.jpg
# 下載完成: images/Y7nvsczb.jpg
# 下載完成: images/0VGDTskb.jpg
# 下載完成: images/pSafUhgb.jpg
# 下載完成: images/3bScuo7b.jpg
# 下載完成: images/aifOQYwb.jpg
# 下載完成: images/678L9Yfb.jpg
# 下載完成: images/NtDE1ISb.jpg
# 下載完成: images/ilAQEm3b.jpg
# 下載完成: images/CZG1HZwb.jpg
# 下載完成: images/lKgKH1eb.jpg
# 下載完成: images/5rw1ne3b.jpg
# 下載完成: images/6v96dj8b.jpg
# 下載完成: images/tL80jRSb.jpg
# 下載完成: images/PLhpiCOb.jpg
# 下載完成: images/3QAOollb.jpg
# 下載完成: images/cJwRVmJb.jpg
# 下載完成: images/Ap5kNQUb.jpg
# 下載完成: images/RoUT76Ab.jpg
# 下載完成: images/EE4K2YRb.jpg
# 下載完成: images/Pxl2vBab.jpg
# 下載完成: images/byMLKk6b.jpg
# 下載完成: images/foRAfqNb.jpg
# 下載完成: images/RoKCFeNb.jpg
# 下載完成: images/hKcbhlMb.jpg
# 下載完成: images/xlX5lXhb.jpg
# 下載完成: images/F2HZjljb.jpg
# 下載完成: images/ySHAzm9b.jpg
# 下載完成: images/vHSH3TBb.jpg
# 下載完成: images/CvIpxcwb.jpg
# 下載完成: images/yocL8ieb.jpg
# 下載完成: images/GdXWYHgb.jpg
# 下載完成: images/4oLiJzwb.jpg
# 下載完成: images/wkqgWyOb.jpg
# 下載完成: images/CB7rAn1b.jpg
# 下載完成: images/p?c1=2&c2=22489583&cv=4.4.0&cj=1

# %%
#使用image_downloader
from image_downloader import download_csv_file_images
download_csv_file_images("cat_images.csv", output_folder="./images2")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-3825f1f32e79> in <cell line: 2>()
#       1 #使用image_downloader
# ----> 2 from image_downloader import download_csv_file_images
#       3 download_csv_file_images("cat_images.csv", output_folder="./images2")
#
# ModuleNotFoundError: No module named 'image_downloader'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
